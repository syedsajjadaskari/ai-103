# %% [markdown]
# # Language: Text Analytics in Action
#
# In this notebook you will learn how to use **Azure AI Language** to:
#
# 1. **Detect the language** of a piece of text
# 2. **Extract key phrases** from a document
# 3. **Analyze sentiment** (positive / negative / neutral)
# 4. **Recognize named entities** (people, places, organizations, etc.)
#
# ---
#
# ### Prerequisites: Deploy the Azure Resource
#
# Before running this notebook, you need an **Azure AI Language** resource. Instead of configuring it manually in the Azure Portal, deploy the included **ARM template** which creates the resource in the correct configuration automatically.
#
# > **Tip:** Open `deploy-language.parameters.json` to customize the resource name, region, or SKU before deploying. The default SKU is **S** (paid). Change it to **F0** for the free tier.
#
# **1. Deploy the resource** — run the cell below (replace `<your-resource-group>`):

# %%
import subprocess, shutil

# ⚠️ Replace <your-resource-group> with your actual resource group name
RESOURCE_GROUP = "Foundry"

# Resolve the full path to the Azure CLI (needed for Windows where az is a .cmd file)
AZ = shutil.which("az")
if not AZ:
    raise FileNotFoundError("Azure CLI (az) not found. Install it from https://learn.microsoft.com/cli/azure/install-azure-cli")

result = subprocess.run(
    [AZ, "deployment", "group", "create",
     "--resource-group", RESOURCE_GROUP,
     "--template-file", "deploy-language.json",
     "--parameters", "deploy-language.parameters.json"],
    capture_output=True, text=True, encoding="utf-8"
)
print(result.stdout)
if result.returncode != 0:
    print("ERROR:", result.stderr)
# Out:
# {
#   "id": "/subscriptions/ff86f0f3-cbf4-4641-9845-300dd46ca8c9/resourceGroups/Foundry/providers/Microsoft.Resources/deployments/deploy-language",
#   "location": null,
#   "name": "deploy-language",
#   "properties": {
#     "correlationId": "b454f150-8ca8-4ab2-97ff-594020d78346",
#     "debugSetting": null,
#     "dependencies": [],
#     "diagnostics": null,
#     "duration": "PT16.8538595S",
#     "error": null,
#     "extensions": [],
#     "mode": "Incremental",
#     "onErrorDeployment": null,
#     "outputResources": [
#       {
#         "apiVersion": null,
#         "extension": null,
#         "id": "/subscriptions/ff86f0f3-cbf4-4641-9845-300dd46ca8c9/resourceGroups/Foundry/providers/Microsoft.CognitiveServices/accounts/foundry-demo-language",
#         "identifiers": null,
#         "resourceGroup": "Foundry",
#         "resourceType": "Microsoft.CognitiveServices/accounts"
#       }
#     ],
#     "outputs": {
#       "languageEndpoint": {
#         "type": "String",
#         "value": "https://foundry-demo-language.cognitiveservices.azure.com/"
#       },
#       "resourceId": {
#         "type": "String",
#         "value": "/subscriptions/ff86f0f3-cbf4-4641-9845-300dd46ca8c9/resourceGroups/Foundry/providers/Microsoft.CognitiveServices/accounts/foundry-demo-language"
#       }
#     },
#     "parameters": {
#       "accountName": {
#         "type": "String",
#         "value": "foundry-demo-language"
#       },
#       "location": {
#         "type": "String",
#         "value": "eastus2"
#       },
#       "sku": {
#         "type": "String",
#         "value": "S"
#       }
#     },
#     "parametersLink": null,
#     "providers": [
#       {
#         "id": null,
#         "namespace": "Microsoft.CognitiveServices",
#         "providerAuthorizationConsentState": null,
#         "registrationPolicy": null,
#         "registrationState": null,
#         "resourceTypes": [
#           {
#             "aliases": null,
#             "apiProfiles": null,
#             "apiVersions": null,
#             "capabilities": null,
#             "defaultApiVersion": null,
#             "locationMappings": null,
#             "locations": [
#               "eastus2"
#             ],
#             "properties": null,
#             "resourceType": "accounts",
#             "zoneMappings": null
#           }
#         ]
#       }
#     ],
#     "provisioningState": "Succeeded",
#     "templateHash": "171902706501133607",
#     "templateLink": null,
#     "timestamp": "2026-02-19T11:45:20.864237+00:00",
#     "validatedResources": null,
#     "validationLevel": null
#   },
#   "resourceGroup": "Foundry",
#   "tags": null,
#   "type": "Microsoft.Resources/deployments"
# }

# %% [markdown]
# **2. Assign the required RBAC role** so your identity can use the resource (replace `<your-resource-group>`):
#
# > **Note:** RBAC role assignments can take **1–2 minutes** to propagate. If you get a 401 error on your first run, wait a moment and try again.

# %%
import subprocess, shutil

RESOURCE_GROUP = "Foundry"
AZ = shutil.which("az")
if not AZ:
    raise FileNotFoundError("Azure CLI (az) not found. Install it from https://learn.microsoft.com/cli/azure/install-azure-cli")

# Step A: Get the signed-in user's Object ID
user_result = subprocess.run(
    [AZ, "ad", "signed-in-user", "show", "--query", "id", "-o", "tsv"],
    capture_output=True, text=True, encoding="utf-8"
)
user_id = user_result.stdout.strip()
print(f"Your User ID: {user_id}")

# Step B: Get the resource ID from the deployment output
scope_result = subprocess.run(
    [AZ, "deployment", "group", "show",
     "--resource-group", RESOURCE_GROUP,
     "--name", "deploy-language",
     "--query", "properties.outputs.resourceId.value", "-o", "tsv"],
    capture_output=True, text=True, encoding="utf-8"
)
resource_id = scope_result.stdout.strip()
print(f"Resource ID:  {resource_id}")

# Step C: Assign the RBAC role
role_result = subprocess.run(
    [AZ, "role", "assignment", "create",
     "--assignee", user_id,
     "--role", "Cognitive Services User",
     "--scope", resource_id],
    capture_output=True, text=True, encoding="utf-8"
)
print(role_result.stdout)
if role_result.returncode != 0:
    print("ERROR:", role_result.stderr)
# Out:
# Your User ID: c417f445-fdf8-46d3-8bd0-4cbf2dd485b1
# Resource ID:  /subscriptions/ff86f0f3-cbf4-4641-9845-300dd46ca8c9/resourceGroups/Foundry/providers/Microsoft.CognitiveServices/accounts/foundry-demo-language
# {
#   "condition": null,
#   "conditionVersion": null,
#   "createdBy": "c417f445-fdf8-46d3-8bd0-4cbf2dd485b1",
#   "createdOn": "2026-02-18T15:26:32.428040+00:00",
#   "delegatedManagedIdentityResourceId": null,
#   "description": null,
#   "id": "/subscriptions/ff86f0f3-cbf4-4641-9845-300dd46ca8c9/resourceGroups/Foundry/providers/Microsoft.CognitiveServices/accounts/foundry-demo-language/providers/Microsoft.Authorization/roleAssignments/1cb81917-faed-47a4-80fb-fb05db452fbb",
#   "name": "1cb81917-faed-47a4-80fb-fb05db452fbb",
#   "principalId": "c417f445-fdf8-46d3-8bd0-4cbf2dd485b1",
#   "principalName": "Chris@azuredemosolutions.com",
#   "principalType": "User",
#   "resourceGroup": "Foundry",
#   "roleDefinitionId": "/subscriptions/ff86f0f3-cbf4-4641-9845-300dd46ca8c9/providers/Microsoft.Authorization/roleDefinitions/a97b65f3-24c7-4388-baec-2e87135dc908",
#   "roleDefinitionName": "Cognitive Services User",
#   "scope": "/subscriptions/ff86f0f3-cbf4-4641-9845-300dd46ca8c9/resourceGroups/Foundry/providers/Microsoft.CognitiveServices/accounts/foundry-demo-language",
#   "type": "Microsoft.Authorization/roleAssignments",
#   "updatedBy": "c417f445-fdf8-46d3-8bd0-4cbf2dd485b1",
#   "updatedOn": "2026-02-18T15:26:32.428040+00:00"
# }

# %% [markdown]
# **3. Update the `.env` file** in this folder with the endpoint from the deployment output:
#
# ```
# LANGUAGE_ENDPOINT="https://<your-account-name>.cognitiveservices.azure.com/"
# ```
#
# You can retrieve this value by running the cell below (replace `<your-resource-group>`):

# %%
import subprocess, shutil

RESOURCE_GROUP = "Foundry"
AZ = shutil.which("az")
if not AZ:
    raise FileNotFoundError("Azure CLI (az) not found. Install it from https://learn.microsoft.com/cli/azure/install-azure-cli")

result = subprocess.run(
    [AZ, "deployment", "group", "show",
     "--resource-group", RESOURCE_GROUP,
     "--name", "deploy-language",
     "--query", "properties.outputs"],
    capture_output=True, text=True, encoding="utf-8"
)
print(result.stdout)
if result.returncode != 0:
    print("ERROR:", result.stderr)
# Out:
# {
#   "languageEndpoint": {
#     "type": "String",
#     "value": "https://foundry-demo-language.cognitiveservices.azure.com/"
#   },
#   "resourceId": {
#     "type": "String",
#     "value": "/subscriptions/ff86f0f3-cbf4-4641-9845-300dd46ca8c9/resourceGroups/Foundry/providers/Microsoft.CognitiveServices/accounts/foundry-demo-language"
#   }
# }

# %% [markdown]
# ### Authentication
#
# This notebook uses **Microsoft Entra ID** (`DefaultAzureCredential`) instead of API keys.
# Make sure you are logged in with `az login`.

# %% [markdown]
# ## Step 1: Install the Text Analytics SDK

# %%
# %pip install azure-ai-textanalytics azure-identity python-dotenv
# Out:
# Requirement already satisfied: azure-ai-textanalytics in /Users/christophernett/courses/.venv312/lib/python3.12/site-packages (5.3.0)
# Requirement already satisfied: azure-identity in /Users/christophernett/courses/.venv312/lib/python3.12/site-packages (1.25.2)
# Requirement already satisfied: python-dotenv in /Users/christophernett/courses/.venv312/lib/python3.12/site-packages (1.2.1)
# Requirement already satisfied: azure-core<2.0.0,>=1.24.0 in /Users/christophernett/courses/.venv312/lib/python3.12/site-packages (from azure-ai-textanalytics) (1.38.1)
# Requirement already satisfied: azure-common~=1.1 in /Users/christophernett/courses/.venv312/lib/python3.12/site-packages (from azure-ai-textanalytics) (1.1.28)
# Requirement already satisfied: isodate<1.0.0,>=0.6.1 in /Users/christophernett/courses/.venv312/lib/python3.12/site-packages (from azure-ai-textanalytics) (0.7.2)
# Requirement already satisfied: typing-extensions>=4.0.1 in /Users/christophernett/courses/.venv312/lib/python3.12/site-packages (from azure-ai-textanalytics) (4.15.0)
# Requirement already satisfied: requests>=2.21.0 in /Users/christophernett/courses/.venv312/lib/python3.12/site-packages (from azure-core<2.0.0,>=1.24.0->azure-ai-textanalytics) (2.32.5)
# Requirement already satisfied: cryptography>=2.5 in /Users/christophernett/courses/.venv312/lib/python3.12/site-packages (from azure-identity) (46.0.5)
# Requirement already satisfied: msal>=1.31.0 in /Users/christophernett/courses/.venv312/lib/python3.12/site-packages (from azure-identity) (1.34.0)
# Requirement already satisfied: msal-extensions>=1.2.0 in /Users/christophernett/courses/.venv312/lib/python3.12/site-packages (from azure-identity) (1.3.1)
# Requirement already satisfied: cffi>=2.0.0 in /Users/christophernett/courses/.venv312/lib/python3.12/site-packages (from cryptography>=2.5->azure-identity) (2.0.0)
# Requirement already satisfied: pycparser in /Users/christophernett/courses/.venv312/lib/python3.12/site-packages (from cffi>=2.0.0->cryptography>=2.5->azure-identity) (3.0)
# Requirement already satisfied: PyJWT<3,>=1.0.0 in /Users/christophernett/courses/.venv312/lib/python3.12/site-packages (from PyJWT[crypto]<3,>=1.0.0->msal>=1.31.0->azure-identity) (2.11.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/christophernett/courses/.venv312/lib/python3.12/site-packages (from requests>=2.21.0->azure-core<2.0.0,>=1.24.0->azure-ai-textanalytics) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/christophernett/courses/.venv312/lib/python3.12/site-packages (from requests>=2.21.0->azure-core<2.0.0,>=1.24.0->azure-ai-textanalytics) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/christophernett/courses/.venv312/lib/python3.12/site-packages (from requests>=2.21.0->azure-core<2.0.0,>=1.24.0->azure-ai-textanalytics) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/christophernett/courses/.venv312/lib/python3.12/site-packages (from requests>=2.21.0->azure-core<2.0.0,>=1.24.0->azure-ai-textanalytics) (2026.1.4)
#
# [notice] A new release of pip is available: 26.0 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Step 2: Load Environment Variables and Create the Client

# %%
import os
from dotenv import load_dotenv
from azure.ai.textanalytics import TextAnalyticsClient
from azure.identity import DefaultAzureCredential

load_dotenv(override=True)

language_endpoint = os.getenv("LANGUAGE_ENDPOINT")

# Authenticate via Entra ID (uses az login credentials)
credential = DefaultAzureCredential()

ta_client = TextAnalyticsClient(
    endpoint=language_endpoint,
    credential=credential,
)

print("Endpoint:", language_endpoint)
print("Client ready:", ta_client is not None)
# Out:
# Endpoint: https://foundry-demo-language.cognitiveservices.azure.com/
# Client ready: True

# %% [markdown]
# ## Step 3: Detect Language
#
# Pass sentences in different languages and the service will tell you
# which language each one is written in.

# %%
multilingual_samples = [
    "Bonjour, comment allez-vous aujourd'hui ?",
    "Ich lerne gerne neue Programmiersprachen.",
    "La inteligencia artificial está cambiando el mundo.",
]

detection_results = ta_client.detect_language(documents=multilingual_samples)

for doc, result in zip(multilingual_samples, detection_results):
    print(f"Text: {doc}")
    print(f"  → Language: {result.primary_language.name} "
          f"(confidence: {result.primary_language.confidence_score:.0%})")
    print()
# Out:
# Text: Bonjour, comment allez-vous aujourd'hui ?
#   → Language: French (confidence: 100%)
#
# Text: Ich lerne gerne neue Programmiersprachen.
#   → Language: German (confidence: 100%)
#
# Text: La inteligencia artificial está cambiando el mundo.
#   → Language: Spanish (confidence: 94%)

# %% [markdown]
# ## Step 4: Extract Key Phrases
#
# Key phrase extraction pulls out the most important terms from your text,
# which is useful for indexing, tagging, or summarization.

# %%
tech_paragraph = [
    "Microsoft Azure provides a wide range of cloud services including "
    "virtual machines, Kubernetes clusters, serverless functions, and "
    "managed databases that help organizations scale their infrastructure."
]

kp_results = ta_client.extract_key_phrases(documents=tech_paragraph)

print("Key phrases found:")
for phrase in kp_results[0].key_phrases:
    print(f"  • {phrase}")
# Out:
# Key phrases found:
#   • Microsoft Azure
#   • wide range
#   • cloud services
#   • virtual machines
#   • Kubernetes clusters
#   • serverless functions
#   • managed databases
#   • organizations
#   • infrastructure

# %% [markdown]
# ## Step 5: Analyze Sentiment
#
# Sentiment analysis classifies each sentence as **positive**, **negative**,
# or **neutral**. This is invaluable for processing customer feedback,
# reviews, or support tickets.

# %%
review_samples = [
    "The new update is fantastic -- performance improved dramatically and the UI feels much smoother.",
    "I've been waiting three weeks for a response from support and still haven't heard back.",
    "The package arrived on Tuesday as scheduled.",
]

sentiment_results = ta_client.analyze_sentiment(documents=review_samples)

for result in sentiment_results:
    sentence = result.sentences[0]
    print(f"Sentiment: {sentence.sentiment.upper():>8}  │  {sentence.text}")
# Out:
# Sentiment: POSITIVE  │  The new update is fantastic -- performance improved dramatically and the UI feels much smoother.
# Sentiment: NEGATIVE  │  I've been waiting three weeks for a response from support and still haven't heard back.
# Sentiment:  NEUTRAL  │  The package arrived on Tuesday as scheduled.

# %% [markdown]
# ## Step 6: Recognize Named Entities
#
# Named Entity Recognition (NER) identifies real-world objects such as
# people, places, companies, dates, and monetary values.

# %%
news_snippets = [
    "In January 2025, OpenAI announced a partnership with Microsoft "
    "to invest $10 billion in artificial intelligence research at "
    "their campus in San Francisco."
]

ner_results = ta_client.recognize_entities(documents=news_snippets)

print(f"{'Entity':<25} {'Category':<15} {'Confidence'}")
print("-" * 55)
for entity in ner_results[0].entities:
    print(f"{entity.text:<25} {entity.category:<15} {entity.confidence_score:.0%}")
# Out:
# Entity                    Category        Confidence
# -------------------------------------------------------
# January 2025              DateTime        100%
# OpenAI                    Organization    91%
# Microsoft                 Organization    100%
# $10 billion               Quantity        100%
# artificial intelligence   Skill           97%
# research                  Skill           50%
# campus                    Location        89%
# San Francisco             Location        100%
