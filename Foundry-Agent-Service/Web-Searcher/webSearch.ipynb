# %% [markdown]
# # Building an Agent That Can Search the Web
#
# In this notebook, we will build an AI agent that has the power to **search the internet** in real time. Unlike a basic chatbot that only knows what it was trained on, this agent can look up current information to answer your questions.
#
# We will use Microsoft Foundry's `WebSearchPreviewTool` to give our agent live web access.

# %% [markdown]
# ## Step 1: Install Packages
#
# Run the cell below to install all the Python packages we need.

# %%
# Install the required libraries for working with Foundry agents and web search
# %pip install azure-ai-projects==2.0.0b2 openai==1.109.1 python-dotenv azure-identity
# Out:
# Requirement already satisfied: azure-ai-projects==2.0.0b2 in /Users/christophernett/udemy/MicrosoftFoundry/.venv/lib/python3.12/site-packages (2.0.0b2)
# Requirement already satisfied: openai==1.109.1 in /Users/christophernett/udemy/MicrosoftFoundry/.venv/lib/python3.12/site-packages (1.109.1)
# Requirement already satisfied: python-dotenv in /Users/christophernett/udemy/MicrosoftFoundry/.venv/lib/python3.12/site-packages (1.2.1)
# Requirement already satisfied: azure-identity in /Users/christophernett/udemy/MicrosoftFoundry/.venv/lib/python3.12/site-packages (1.25.2)
# Requirement already satisfied: isodate>=0.6.1 in /Users/christophernett/udemy/MicrosoftFoundry/.venv/lib/python3.12/site-packages (from azure-ai-projects==2.0.0b2) (0.7.2)
# Requirement already satisfied: azure-core>=1.35.0 in /Users/christophernett/udemy/MicrosoftFoundry/.venv/lib/python3.12/site-packages (from azure-ai-projects==2.0.0b2) (1.38.1)
# Requirement already satisfied: typing-extensions>=4.6.0 in /Users/christophernett/udemy/MicrosoftFoundry/.venv/lib/python3.12/site-packages (from azure-ai-projects==2.0.0b2) (4.15.0)
# Requirement already satisfied: azure-storage-blob>=12.15.0 in /Users/christophernett/udemy/MicrosoftFoundry/.venv/lib/python3.12/site-packages (from azure-ai-projects==2.0.0b2) (12.28.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/christophernett/udemy/MicrosoftFoundry/.venv/lib/python3.12/site-packages (from openai==1.109.1) (4.12.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/christophernett/udemy/MicrosoftFoundry/.venv/lib/python3.12/site-packages (from openai==1.109.1) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/christophernett/udemy/MicrosoftFoundry/.venv/lib/python3.12/site-packages (from openai==1.109.1) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /Users/christophernett/udemy/MicrosoftFoundry/.venv/lib/python3.12/site-packages (from openai==1.109.1) (0.13.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /Users/christophernett/udemy/MicrosoftFoundry/.venv/lib/python3.12/site-packages (from openai==1.109.1) (2.12.5)
# Requirement already satisfied: sniffio in /Users/christophernett/udemy/MicrosoftFoundry/.venv/lib/python3.12/site-packages (from openai==1.109.1) (1.3.1)
# Requirement already satisfied: tqdm>4 in /Users/christophernett/udemy/MicrosoftFoundry/.venv/lib/python3.12/site-packages (from openai==1.109.1) (4.67.3)
# Requirement already satisfied: idna>=2.8 in /Users/christophernett/udemy/MicrosoftFoundry/.venv/lib/python3.12/site-packages (from anyio<5,>=3.5.0->openai==1.109.1) (3.11)
# Requirement already satisfied: certifi in /Users/christophernett/udemy/MicrosoftFoundry/.venv/lib/python3.12/site-packages (from httpx<1,>=0.23.0->openai==1.109.1) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in /Users/christophernett/udemy/MicrosoftFoundry/.venv/lib/python3.12/site-packages (from httpx<1,>=0.23.0->openai==1.109.1) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Users/christophernett/udemy/MicrosoftFoundry/.venv/lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai==1.109.1) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/christophernett/udemy/MicrosoftFoundry/.venv/lib/python3.12/site-packages (from pydantic<3,>=1.9.0->openai==1.109.1) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /Users/christophernett/udemy/MicrosoftFoundry/.venv/lib/python3.12/site-packages (from pydantic<3,>=1.9.0->openai==1.109.1) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/christophernett/udemy/MicrosoftFoundry/.venv/lib/python3.12/site-packages (from pydantic<3,>=1.9.0->openai==1.109.1) (0.4.2)
# Requirement already satisfied: cryptography>=2.5 in /Users/christophernett/udemy/MicrosoftFoundry/.venv/lib/python3.12/site-packages (from azure-identity) (46.0.5)
# Requirement already satisfied: msal>=1.31.0 in /Users/christophernett/udemy/MicrosoftFoundry/.venv/lib/python3.12/site-packages (from azure-identity) (1.34.0)
# Requirement already satisfied: msal-extensions>=1.2.0 in /Users/christophernett/udemy/MicrosoftFoundry/.venv/lib/python3.12/site-packages (from azure-identity) (1.3.1)
# Requirement already satisfied: requests>=2.21.0 in /Users/christophernett/udemy/MicrosoftFoundry/.venv/lib/python3.12/site-packages (from azure-core>=1.35.0->azure-ai-projects==2.0.0b2) (2.32.5)
# Requirement already satisfied: cffi>=2.0.0 in /Users/christophernett/udemy/MicrosoftFoundry/.venv/lib/python3.12/site-packages (from cryptography>=2.5->azure-identity) (2.0.0)
# Requirement already satisfied: pycparser in /Users/christophernett/udemy/MicrosoftFoundry/.venv/lib/python3.12/site-packages (from cffi>=2.0.0->cryptography>=2.5->azure-identity) (3.0)
# Requirement already satisfied: PyJWT<3,>=1.0.0 in /Users/christophernett/udemy/MicrosoftFoundry/.venv/lib/python3.12/site-packages (from PyJWT[crypto]<3,>=1.0.0->msal>=1.31.0->azure-identity) (2.11.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/christophernett/udemy/MicrosoftFoundry/.venv/lib/python3.12/site-packages (from requests>=2.21.0->azure-core>=1.35.0->azure-ai-projects==2.0.0b2) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/christophernett/udemy/MicrosoftFoundry/.venv/lib/python3.12/site-packages (from requests>=2.21.0->azure-core>=1.35.0->azure-ai-projects==2.0.0b2) (2.6.3)
#
# [notice] A new release of pip is available: 26.0 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Step 2: Load Settings and Import Libraries
#
# We load our project settings from a `.env` file and import all the classes we need. Notice we are also importing `WebSearchPreviewTool` — this is the tool that gives our agent internet access.

# %%
# Standard library for accessing environment variables
import os

# Reads key-value pairs from a .env file into the environment
from dotenv import load_dotenv

# Handles Azure login credentials automatically
from azure.identity import DefaultAzureCredential

# The main client for connecting to a Foundry project
from azure.ai.projects import AIProjectClient

# PromptAgentDefinition: defines what our agent looks like and how it behaves
# WebSearchPreviewTool: a built-in tool that lets the agent search the web
from azure.ai.projects.models import PromptAgentDefinition, WebSearchPreviewTool

# Load the .env file so we can read our settings
load_dotenv()

# The URL of our Foundry project
my_endpoint = os.getenv("FOUNDRY_PROJECT_ENDPOINT")

# The name of the deployed AI model we want the agent to use
my_model = os.getenv("MODEL_DEPLOYMENT_NAME")

# %% [markdown]
# ## Step 3: Connect to Microsoft Foundry
#
# We create a Foundry client using our endpoint and Azure credentials. This client is our gateway to creating agents and conversations.

# %%
# Open a connection to our Foundry project in the cloud
foundry_client = AIProjectClient(
    endpoint=my_endpoint,
    credential=DefaultAzureCredential(),
)

# %% [markdown]
# ## Step 4: Get the OpenAI Chat Client
#
# The chat client is what we use to send messages and receive responses. Foundry provides an OpenAI-compatible client, so the API feels familiar if you have used OpenAI before.

# %%
# Get an OpenAI-compatible client for sending messages to agents
chat_client = foundry_client.get_openai_client()

# %% [markdown]
# ## Step 5: Create a Web-Enabled Agent
#
# Here we create an agent that has the `WebSearchPreviewTool` attached. This tool allows the agent to perform live web searches when answering questions, so it can find up-to-date information instead of relying only on its training data.

# %%
# Create the web-enabled search agent
# - agent_name: a unique identifier for this agent
# - model: the AI model powering the agent
# - instructions: tells the agent how to behave
# - tools: a list of tools the agent can use (in this case, web search)
search_agent = foundry_client.agents.create_version(
    agent_name="live-search-assistant",
    definition=PromptAgentDefinition(
        model=my_model,
        instructions="You are a research assistant that searches the web to find current, accurate answers to user questions.",
        tools=[
            WebSearchPreviewTool()  # This gives the agent the ability to search the internet
        ]
    )
)

# %% [markdown]
# ## Step 6: Open a Chat Session
#
# We create a new conversation so the agent can track context across multiple messages.

# %%
# Start a fresh conversation — this stores the message history
chat_session = chat_client.conversations.create()
print(f"Created conversation with id: {chat_session.id}")
# Out:
# Created conversation with id: conv_65524b68359cba2300l27PWVLRWaKpSE5rB8H9tjwmRxJGw5op

# %% [markdown]
# ## Step 7: Ask a Question and Get Live Results
#
# Now let us ask our agent a question that requires up-to-date information. The agent will search the web and return a summarized answer.

# %%
# Define the question we want to ask — this is something that needs live web data
question = "What are the top trending technologies in 2026?"

# %%
# Send our question to the web-search agent and wait for the response
# - conversation: keeps this message in context with the chat session
# - extra_body: tells Foundry to route this to our "live-search-assistant" agent
# - input: the question we want answered
response = chat_client.responses.create(
    conversation=chat_session.id,
    extra_body={
        "agent": {
            "name": "live-search-assistant",
            "type": "agent_reference"
        }
    },
    input=question
)

# Print the agent's answer (which includes information from live web results)
print(f"Agent response: {response.output_text}")
# Out:
# Agent response: The top trending technologies in 2025 include a mix of advanced artificial intelligence, connectivity improvements, robotics, and sustainability innovations. Key technologies gaining significant attention are:
#
# 1. Agentic AI & Multimodal Systems: Autonomous AI agents capable of multi-step reasoning and action without human intervention. Applying in areas like self-driving cars, virtual assistants, personalized medicine, and predictive analytics. The AI market is projected to reach $294 billion by 2025.
#
# 2. Generative AI: AI that creates new content such as text, images, music, and code. It is reshaping content creation, software development, and personalized experiences across industries.
#
# 3. 5G-Advanced & 6G Foundations: Faster, low-latency mobile connectivity enabling new applications including IoT, autonomous vehicles, and AR/VR.
#
# 4. Brain-Computer Interfaces (BCIs): Direct communication between the brain and external devices to enhance cognitive abilities and assist with disabilities.
#
# 5. Polyfunctional Robots: Robots capable of performing multiple tasks with flexibility, improving productivity and human-machine synergy.
#
# 6. Quantum Computing: Offering massive computational power for solving complex problems beyond classical computers.
#
# 7. Synthetic Media and AI-Powered Cybersecurity: AI-produced content and AI-driven defense systems to counter increasingly sophisticated cyber threats.
#
# 8. Structural Battery Composites: Materials that combine strength and energy storage, optimizing electric vehicles and aircraft.
#
# 9. Extended Reality (XR): Immersive virtual and augmented reality technologies for work, training, and collaboration.
#
# 10. Sustainability and Clean Energy Technologies: Including AI-driven solutions for energy optimization, nuclear power advancing AI infrastructure, and greener fuels.
#
# Reports from trusted sources such as the World Economic Forum, McKinsey, Forbes, Gartner, MIT Technology Review, and others consistently highlight these trends shaping 2025's technology landscape.
#
# If you want, I can provide detailed explanations or specific examples for each technology.
#
# Sources:
# - World Economic Forum: Top 10 Emerging Technologies of 2025 https://www.weforum.org/stories/2025/06/top-10-emerging-technologies-of-2025/
# - Forbes: Top 10 Technology Trends For 2025 https://www.forbes.com/councils/forbestechcouncil/2025/02/03/top-10-technology-trends-for-2025/
# - McKinsey Technology Trends Outlook 2025 https://www.mckinsey.com/~/media/mckinsey/business%20functions/mckinsey%20digital/our%20insights/the%20top%20trends%20in%20tech%202025/mckinsey-technology-trends-outlook-2025.pdf
# - MIT Technology Review: 10 Breakthrough Technologies 2025 https://www.technologyreview.com/2025/01/03/1109178/10-breakthrough-technologies-2025/
