# %% [markdown]
# ## Combining Multiple Tools in a Single Agent
#
# In this notebook, we give a single agent access to **two** different tools at the same time:
# 1. **Bored Activity API** (via OpenAPI) -- suggests fun activities by category
# 2. **Microsoft Learn Search** (via MCP) -- searches Microsoft's documentation library
#
# The agent decides which tool to use based on the question. We'll even ask a question that requires **both** tools in one answer.

# %% [markdown]
# ### Step 1: Install Packages
#
# We need a handful of libraries to interact with Azure Foundry, parse OpenAPI specs, and authenticate.

# %%
# Install all required packages in one go
# jsonref is needed to resolve $ref pointers inside OpenAPI spec files
# %pip install azure-ai-projects==2.0.0b2 openai==1.109.1 python-dotenv azure-identity jsonref
# Out:
# Requirement already satisfied: azure-ai-projects==2.0.0b2 in /Users/christophernett/courses/.venv312/lib/python3.12/site-packages (2.0.0b2)
# Requirement already satisfied: openai==1.109.1 in /Users/christophernett/courses/.venv312/lib/python3.12/site-packages (1.109.1)
# Requirement already satisfied: python-dotenv in /Users/christophernett/courses/.venv312/lib/python3.12/site-packages (1.2.1)
# Requirement already satisfied: azure-identity in /Users/christophernett/courses/.venv312/lib/python3.12/site-packages (1.25.2)
# Requirement already satisfied: jsonref in /Users/christophernett/courses/.venv312/lib/python3.12/site-packages (1.1.0)
# Requirement already satisfied: isodate>=0.6.1 in /Users/christophernett/courses/.venv312/lib/python3.12/site-packages (from azure-ai-projects==2.0.0b2) (0.7.2)
# Requirement already satisfied: azure-core>=1.35.0 in /Users/christophernett/courses/.venv312/lib/python3.12/site-packages (from azure-ai-projects==2.0.0b2) (1.38.1)
# Requirement already satisfied: typing-extensions>=4.6.0 in /Users/christophernett/courses/.venv312/lib/python3.12/site-packages (from azure-ai-projects==2.0.0b2) (4.15.0)
# Requirement already satisfied: azure-storage-blob>=12.15.0 in /Users/christophernett/courses/.venv312/lib/python3.12/site-packages (from azure-ai-projects==2.0.0b2) (12.28.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/christophernett/courses/.venv312/lib/python3.12/site-packages (from openai==1.109.1) (4.12.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/christophernett/courses/.venv312/lib/python3.12/site-packages (from openai==1.109.1) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/christophernett/courses/.venv312/lib/python3.12/site-packages (from openai==1.109.1) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /Users/christophernett/courses/.venv312/lib/python3.12/site-packages (from openai==1.109.1) (0.13.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /Users/christophernett/courses/.venv312/lib/python3.12/site-packages (from openai==1.109.1) (2.12.5)
# Requirement already satisfied: sniffio in /Users/christophernett/courses/.venv312/lib/python3.12/site-packages (from openai==1.109.1) (1.3.1)
# Requirement already satisfied: tqdm>4 in /Users/christophernett/courses/.venv312/lib/python3.12/site-packages (from openai==1.109.1) (4.67.3)
# Requirement already satisfied: idna>=2.8 in /Users/christophernett/courses/.venv312/lib/python3.12/site-packages (from anyio<5,>=3.5.0->openai==1.109.1) (3.11)
# Requirement already satisfied: certifi in /Users/christophernett/courses/.venv312/lib/python3.12/site-packages (from httpx<1,>=0.23.0->openai==1.109.1) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in /Users/christophernett/courses/.venv312/lib/python3.12/site-packages (from httpx<1,>=0.23.0->openai==1.109.1) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Users/christophernett/courses/.venv312/lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai==1.109.1) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/christophernett/courses/.venv312/lib/python3.12/site-packages (from pydantic<3,>=1.9.0->openai==1.109.1) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /Users/christophernett/courses/.venv312/lib/python3.12/site-packages (from pydantic<3,>=1.9.0->openai==1.109.1) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/christophernett/courses/.venv312/lib/python3.12/site-packages (from pydantic<3,>=1.9.0->openai==1.109.1) (0.4.2)
# Requirement already satisfied: cryptography>=2.5 in /Users/christophernett/courses/.venv312/lib/python3.12/site-packages (from azure-identity) (46.0.5)
# Requirement already satisfied: msal>=1.31.0 in /Users/christophernett/courses/.venv312/lib/python3.12/site-packages (from azure-identity) (1.34.0)
# Requirement already satisfied: msal-extensions>=1.2.0 in /Users/christophernett/courses/.venv312/lib/python3.12/site-packages (from azure-identity) (1.3.1)
# Requirement already satisfied: requests>=2.21.0 in /Users/christophernett/courses/.venv312/lib/python3.12/site-packages (from azure-core>=1.35.0->azure-ai-projects==2.0.0b2) (2.32.5)
# Requirement already satisfied: cffi>=2.0.0 in /Users/christophernett/courses/.venv312/lib/python3.12/site-packages (from cryptography>=2.5->azure-identity) (2.0.0)
# Requirement already satisfied: pycparser in /Users/christophernett/courses/.venv312/lib/python3.12/site-packages (from cffi>=2.0.0->cryptography>=2.5->azure-identity) (3.0)
# Requirement already satisfied: PyJWT<3,>=1.0.0 in /Users/christophernett/courses/.venv312/lib/python3.12/site-packages (from PyJWT[crypto]<3,>=1.0.0->msal>=1.31.0->azure-identity) (2.11.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/christophernett/courses/.venv312/lib/python3.12/site-packages (from requests>=2.21.0->azure-core>=1.35.0->azure-ai-projects==2.0.0b2) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/christophernett/courses/.venv312/lib/python3.12/site-packages (from requests>=2.21.0->azure-core>=1.35.0->azure-ai-projects==2.0.0b2) (2.6.3)
#
# [notice] A new release of pip is available: 26.0 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Step 2: Load Configuration
#
# All sensitive values live in a `.env` file. We load them here so the rest of the notebook can reference them safely.

# %%
# os lets us read environment variables
import os

# load_dotenv reads your .env file and sets the variables for this session
from dotenv import load_dotenv

# DefaultAzureCredential handles authentication automatically
from azure.identity import DefaultAzureCredential

# AIProjectClient is the main gateway to Azure Foundry
from azure.ai.projects import AIProjectClient

# PromptAgentDefinition defines how our agent behaves
# MCPTool lets us connect to a Model Context Protocol server
from azure.ai.projects.models import PromptAgentDefinition, MCPTool

# jsonref resolves $ref pointers inside JSON files (needed for OpenAPI specs)
import jsonref

# Pull in all environment variables from the .env file
load_dotenv()

# The Foundry project URL that the SDK will call
my_endpoint = os.getenv("FOUNDRY_PROJECT_ENDPOINT")

# Which deployed language model the agent should use
my_model = os.getenv("MODEL_DEPLOYMENT_NAME")

# %% [markdown]
# ### Step 3: Connect to Foundry
#
# Create a project client that we will use for everything -- creating agents, listing connections, and more.

# %%
# Initialize the Foundry client with our endpoint and credentials
foundry_client = AIProjectClient(
    endpoint=my_endpoint,
    credential=DefaultAzureCredential(),
)

# %% [markdown]
# ### Step 4: Create the Chat Client
#
# The chat client wraps the OpenAI API and lets us create conversations and send messages.

# %%
# This returns an OpenAI-compatible client already wired to your Foundry project
chat_client = foundry_client.get_openai_client()

# %% [markdown]
# ### Step 5: Load the Activity API Tool (OpenAPI)
#
# We read a local JSON file that describes the Bored Activity API using the OpenAPI standard.
# Then we wrap it in a tool definition the agent can use to search for activities by category.

# %%
# Open the OpenAPI spec file and parse it, resolving any internal $ref pointers
with open("./activities_openapi.json", "r", encoding="utf-8") as spec_file:
    activity_api_spec = jsonref.loads(spec_file.read())

# Package the parsed spec into a tool dictionary the agent understands
# "type": "openapi" tells the agent this is an external API it can call
# "auth": {"type": "anonymous"} means no API key is required
activity_api_tool = {
    "type": "openapi",
    "openapi": {
        "name": "activities",
        "spec": activity_api_spec,
        "auth": {
            "type": "anonymous"
        },
    },
}

# %% [markdown]
# ### Step 6: Set Up the MCP Tool
#
# Now we configure the MCP tool that connects to the Microsoft Learn search server.
# The Microsoft Learn MCP server is a **public endpoint**, so no project connection or
# authentication is needed. For private MCP servers, you would also pass a `project_connection_id`.

# %%
# Create an MCP tool that points to the Microsoft Learn search endpoint
# server_label is a friendly name you pick for this tool
# server_url is the public MCP endpoint provided by Microsoft
# require_approval="never" means the agent can call it without asking permission first
learn_mcp_tool = MCPTool(
    server_label="microsoft_learn_server",
    server_url="https://learn.microsoft.com/api/mcp",
    require_approval="never",
)

# %% [markdown]
# ### Step 7: Create an Agent with Both Tools
#
# This is where the magic happens. We give a single agent access to **two** different tools:
# 1. The Bored Activity API (OpenAPI) -- for suggesting activities by category
# 2. The Microsoft Learn Search (MCP) -- for finding documentation and tutorials
#
# The agent decides which tool to use based on the question.

# %%
# Pick a descriptive name for this multi-tool agent
combo_agent_name = "multi-skill-assistant"

# Register the agent in Foundry with both tools attached
combo_agent = foundry_client.agents.create_version(
    agent_name=combo_agent_name,
    definition=PromptAgentDefinition(
        # The language model that powers this agent
        model=my_model,
        # High-level instructions telling the agent what it can do
        instructions="You are a helpful assistant with two skills: (1) you can suggest fun activities using the Bored Activity API, and (2) you can search Microsoft Learn documentation. Use whichever tool is appropriate for the user's question, or both if the question covers multiple topics.",
        # Pass both tools as a list -- the agent can use either or both in a single response
        tools=[activity_api_tool, learn_mcp_tool],
    ),
)

# Confirm the agent was created
print(f"Agent created -- Name: {combo_agent.name}, ID: {combo_agent.id}")
# Out:
# Agent created -- Name: multi-skill-assistant, ID: multi-skill-assistant:2

# %% [markdown]
# ### Step 8: Open a Chat Session
#
# Every conversation with the agent needs its own session so the agent can keep track of context.

# %%
# Start a brand-new conversation thread
chat_session = chat_client.conversations.create()

# Print the session ID for debugging
print(f"Chat session opened -- ID: {chat_session.id}")
# Out:
# Chat session opened -- ID: conv_c37c2c838460948600aTVdOTplbDn2iGFFGC40i2j17vJNr6dO

# %% [markdown]
# ### Step 9: Test the Multi-Tool Agent
#
# We ask a single question that requires **both** tools -- an activity suggestion and a Microsoft Learn search.
# The agent figures out which tool handles which part.

# %%
# This question intentionally covers two different topics so the agent must use both tools
test_question = "I'm bored -- suggest a few DIY activities I can try, and also find me a Microsoft Learn tutorial about deploying Azure Functions."

# %%
# Send the question to our multi-tool agent
result = chat_client.responses.create(
    # Attach this message to the conversation we opened earlier
    conversation=chat_session.id,
    # Tell the service which agent should handle this request
    extra_body={
        "agent": {
            "name": combo_agent_name,
            "type": "agent_reference",
        }
    },
    # The user's question
    input=test_question,
)

# Show the agent's combined answer
print(f"Agent response: {result.output_text}")
# Out:
# Agent response: Here are some DIY activities you can try:
# 1. Find a DIY to do (easy and quick)
# 2. Fix something that's broken in your house (minor challenges)
# 3. Create a compost pile (more challenging and takes hours)
# 4. Make tie dye shirts (fun and takes a few hours)
# 5. Make a scrapbook with pictures of your favorite memories (creative and a few hours)
# 6. Learn woodworking (a longer-term project taking weeks)
#
# For deploying Azure Functions, I found a useful Microsoft Learn tutorial titled "Tutorial: Host an MCP server on Azure Functions." It covers deployment steps with different programming languages like Python, C#, and TypeScript.
#
# You can check it out here:
# https://learn.microsoft.com/azure/azure-functions/functions-mcp-tutorial#deploy-the-mcp-server-project
#
# Let me know if you'd like a summary or specific steps from the tutorial!
